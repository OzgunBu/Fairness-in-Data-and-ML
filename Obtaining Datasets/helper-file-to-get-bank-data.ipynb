# %%
import pandas as pd
import numpy as np

# %%
ls
# Out:
# bank-additional-full.csv*               helper-file-to-get-bank-data.ipynb
# bank.csv                                helper-file-to-get-compas-scores.ipynb
# compas.csv                              notebook.tex

# %%
online_df = pd.read_csv('bank-additional-full.csv',sep=';')

# %%
online_df.head()
# Out:
#    age        job  marital    education  default housing loan    contact  \
# 0   56  housemaid  married     basic.4y       no      no   no  telephone
# 1   57   services  married  high.school  unknown      no   no  telephone
# 2   37   services  married  high.school       no     yes   no  telephone
# 3   40     admin.  married     basic.6y       no      no   no  telephone
# 4   56   services  married  high.school       no      no  yes  telephone
#
#   month day_of_week ...  campaign  pdays  previous     poutcome emp.var.rate  \
# 0   may         mon ...         1    999         0  nonexistent          1.1
# 1   may         mon ...         1    999         0  nonexistent          1.1
# 2   may         mon ...         1    999         0  nonexistent          1.1
# 3   may         mon ...         1    999         0  nonexistent          1.1
# 4   may         mon ...         1    999         0  nonexistent          1.1
#
#    cons.price.idx  cons.conf.idx  euribor3m  nr.employed   y
# ...

# %%
target_field = 'y'
sensitive_field = 'age'

# %%
online_df[target_field].unique()
# Out:
# array(['no', 'yes'], dtype=object)

# %%
# age will be the sensitive attribute. We define two classes one is ages 25-60, other is not in <25 or >60

# %%
#online_df.loc[online_df['age']>60 ,'age']= 200

# %%
#online_df.loc[online_df['age']<25 ,'age']= 200

# %%
online_df.loc[(online_df['age']<25) | (online_df['age']>60) ,'age']= -200
online_df.loc[(online_df['age']>=25) & (online_df['age']<=60) ,'age']= 200

# %%
online_df.head()
# Out:
#    age        job  marital    education  default housing loan    contact  \
# 0  200  housemaid  married     basic.4y       no      no   no  telephone
# 1  200   services  married  high.school  unknown      no   no  telephone
# 2  200   services  married  high.school       no     yes   no  telephone
# 3  200     admin.  married     basic.6y       no      no   no  telephone
# 4  200   services  married  high.school       no      no  yes  telephone
#
#   month day_of_week ...  campaign  pdays  previous     poutcome emp.var.rate  \
# 0   may         mon ...         1    999         0  nonexistent          1.1
# 1   may         mon ...         1    999         0  nonexistent          1.1
# 2   may         mon ...         1    999         0  nonexistent          1.1
# 3   may         mon ...         1    999         0  nonexistent          1.1
# 4   may         mon ...         1    999         0  nonexistent          1.1
#
#    cons.price.idx  cons.conf.idx  euribor3m  nr.employed   y
# ...

# %%
online_df['age'] = online_df['age'].replace(200, '25-60')
online_df['age'] = online_df['age'].replace(-200, '<25 or >60')

# %%
online_df.head()
# Out:
#      age        job  marital    education  default housing loan    contact  \
# 0  25-60  housemaid  married     basic.4y       no      no   no  telephone
# 1  25-60   services  married  high.school  unknown      no   no  telephone
# 2  25-60   services  married  high.school       no     yes   no  telephone
# 3  25-60     admin.  married     basic.6y       no      no   no  telephone
# 4  25-60   services  married  high.school       no      no  yes  telephone
#
#   month day_of_week ...  campaign  pdays  previous     poutcome emp.var.rate  \
# 0   may         mon ...         1    999         0  nonexistent          1.1
# 1   may         mon ...         1    999         0  nonexistent          1.1
# 2   may         mon ...         1    999         0  nonexistent          1.1
# 3   may         mon ...         1    999         0  nonexistent          1.1
# 4   may         mon ...         1    999         0  nonexistent          1.1
#
# ...

# %%
online_df[sensitive_field].unique()
# Out:
# array(['25-60', '<25 or >60'], dtype=object)

# %%
online_df.to_csv('bank.csv', index=False)

file_df = pd.read_csv('bank.csv')

# %%
file_df.head()
# Out:
#      age        job  marital    education  default housing loan    contact  \
# 0  25-60  housemaid  married     basic.4y       no      no   no  telephone
# 1  25-60   services  married  high.school  unknown      no   no  telephone
# 2  25-60   services  married  high.school       no     yes   no  telephone
# 3  25-60     admin.  married     basic.6y       no      no   no  telephone
# 4  25-60   services  married  high.school       no      no  yes  telephone
#
#   month day_of_week ...  campaign  pdays  previous     poutcome emp.var.rate  \
# 0   may         mon ...         1    999         0  nonexistent          1.1
# 1   may         mon ...         1    999         0  nonexistent          1.1
# 2   may         mon ...         1    999         0  nonexistent          1.1
# 3   may         mon ...         1    999         0  nonexistent          1.1
# 4   may         mon ...         1    999         0  nonexistent          1.1
#
# ...
